# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
names=["nishu",3,"a"]
print(names)
print(names[0])
# Out:
# ['nishu', 3, 'a']
# nishu

# %% [markdown]
# ### accessing list

# %%
names[0]
# Out:
# 'nishu'

# %%
import numpy as np

arr = np.random.rand(2, 2)*100
print(arr)
# Out:
# [[20.10347563 55.61669511]
#  [77.09264682 51.22968371]]

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

a + b       # [5 7 9]
# Out:
# array([5, 7, 9])

# %%
a - b       # [-3 -3 -3]
# Out:
# array([-3, -3, -3])

# %%
a * b       # [4 10 18]
# Out:
# array([ 4, 10, 18])

# %%
import numpy as np, time

lst = list(range(1000000))
arr = np.arange(1000000)

start = time.time()
print(start)
[x*2 for x in lst]
t2=time.time()
print(t2)
print("List:", t2-start)

start = time.time()
arr*2
print("NumPy:", time.time()-start)
# Out:
# 1762067562.4432778
# 1762067562.4890838
# List: 0.045805931091308594
# NumPy: 0.002490520477294922
