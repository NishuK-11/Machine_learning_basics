# %%
from package.math import addition
addition(2,3)
# Out:
# 5

# %%
from package.subpackage.name import printName
printName("ishani")
# Out:
# Hello, ishani!

# %%
from package.math import *
printName("nishu")
# Out:
# Hello, nishu!

# %%
import os
print(os.getcwd())#current working directory
# Out:
# d:\Ai-ml\langraph

# %%
import shutil
shutil.copyfile('numpy.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
with open("numpy.txt", "r") as f:
    print(f.read())
# Out:
# np.sqrt(a)
# np.exp(a)
# np.log(a)
# np.mean(a)
# np.median(a)
# np.std(a)
# np.sum(a)
# np.min(a)
# np.max(a)

# %%
import json
data = {"name":"nishu",'age':20}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "nishu", "age": 20}
# <class 'str'>
# {'name': 'nishu', 'age': 20}
# <class 'dict'>

# %%
import csv
with open('destination.csv',mode='w',newline='\r\n') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['nishu',20])
    writer.writerow(['nishu',20])
    

with open('destination.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# []
# ['nishu', '20']
# []
# ['nishu', '20']
# []

# %%
from datetime import datetime,timedelta
now = datetime.now()
print(now)

yesterday = now-timedelta(days=600000)
print(yesterday)
# Out:
# 2025-11-02 14:26:52.062271
# 0383-02-04 14:26:52.062271

# %%
import time
t1 = time.time()
print(time.time())
time.sleep(5)
t2=time.time()
print(time.time())
print(t1-t2)
# Out:
# 1762073930.3741386
# 1762073935.3794405
# -5.0053019523620605

# %%
import re 
pattern=r'[a-z]+'
text = 'nishu123kumari'
match=re.findall(pattern,text)
print(match)
# Out:
# ['nishu', 'kumari']

# %%
with open('destination.txt','r') as file:
    print(file.read())
# Out:
# hii

# %%
#read line by line
with open('destination.csv','r',newline='') as file:
    for line in file:
        print(line.strip())
# Out:
# name,age
#
# nishu,20
#
# nishu,20

# %%
#writing a file
with open('destination.txt',mode='w') as file:
    file.write('hello nishu\n')

# %%
with open('destination.txt',mode='a') as file:
    file.write('hello ishani')

# %%
lines=["apple\n","mango\n"]
with open('destination.txt',mode='a') as file:
    file.writelines(lines)

# %%
##binary files
data=b'\x00\x01'
with open('example.bin', 'wb')as file:
    file.write(data)

# %%
def countAll(file_path):
    with open(file_path,'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count= sum(len(lines) for line in lines)
    return line_count,word_count,char_count
file_path = 'destination.csv'
lines,words,chars = countAll(file_path)
print(f'Lines:{lines}, words:{words},characters:{chars}')
# Out:
# Lines:6, words:3,characters:36

# %%
#w+=> read and write
with open('example.txt','w+') as file:
    file.write("hello world")
    file.write("this is new line\n")

    file.seek(4)
    content = file.read()
    print(content)
# Out:
# o worldthis is new line

# %%
mkdir ops

# %%
import os
#joining path
dir_name="folder"
file_path="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_path)
print(full_path)
# Out:
# d:\Ai-ml\langraph\folder\file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path}' does not exists")
# Out:
# the path 'example.txt' exists

# %%
path='package'
if os.path.isfile(path):
    print(f"The path '{path}' is a file")
elif os.path.isdir(path):
    print(f"the path '{path}' is a directory")
else:
    print(f"the path '{path}' is neither a file nor a directory")
# Out:
# the path 'package' is a directory

# %%
#getting absolute path
cwd = os.getcwd()
print(f"the current working directory is '{cwd}'")
# Out:
# the current working directory is 'd:\Ai-ml\langraph'

# %%
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory")
